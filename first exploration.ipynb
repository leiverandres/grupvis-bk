# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

CONV_RESULTS_PATH = "./datasets/resultados-preliminares-grupos-conv_781_L.csv"

# %%
data = pd.read_csv(CONV_RESULTS_PATH)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5188 entries, 0 to 5187
# Data columns (total 7 columns):
# CÓDIGO DE GRUPO                 5188 non-null object
# NOMBRE DEL GRUPO                5188 non-null object
# LÍDER DEL GRUPO                 5188 non-null object
# INSTITUCIONES QUE LO AVALAN     5188 non-null object
# GRUPO RECONOCIDO                5188 non-null object
# GRUPO INSCRITO PARA MEDICIÓN    5188 non-null object
# CLASIFICACIÓN DEL GRUPO         5188 non-null object
# dtypes: object(7)
# memory usage: 283.8+ KB

# %%
data.head()
# Out:
#   CÓDIGO DE GRUPO                                   NOMBRE DEL GRUPO  \
# 0      COL0067371                                            INSIGHT
# 1      COL0165935  GRUPO DE INVESTIGACION E INNOVACIÓN EN ENER-\n...
# 2      COL0110982                                   INSTITUTO ALPINA
# 3      COL0120245          GESTIÓN HOSPITALARIA Y POLÍTICAS DE SALUD
# 4      COL0033023  CENTRO DE INVESTIGA- CIÓN Y DESARROLLO AN- DERCOL
#
#                       LÍDER DEL GRUPO  \
# 0  JAVIER OSWALDO RODRÍGUEZ VELÁSQUEZ
# 1     NHORA CECILIA PA- RRA RODRIGUEZ
# 2            BERNADETTE KLOTZ CEBERIO
# 3               JULIO OROZCO AFRICANO
# 4     DANIEL HUMBERTO BUILES MARTÍNEZ
#
#                          INSTITUCIONES QUE LO AVALAN GRUPO RECONOCIDO  \
# 0  ADMINISTRADORA COUNTRY S.A- CENTRO DE IN- VEST...                
# 1                           AES CHIVOR & CIA SCA ESP                
# 2            ALPINA PRODUC- TOS ALIMENTI-\nCIOS S.A.                
# ...

# %%
data["INSTITUCIONES QUE LO AVALAN"].value_counts()
# Out:
# UNIVERSIDAD NACIONAL DE COLOMBIA - OFICIAL                                                                                                       404
# UNIVERSIDAD DE ANTIOQUIA - UDEA                                                                                                                  127
# UNIVERSIDAD NA-\nCIONAL DE COLOMBIA - OFICIAL                                                                                                    127
# UNIVERSIDAD DE\nANTIOQUIA - UDEA                                                                                                                 125
# UNIVERSIDAD PEDAGÓGICA Y TEC- NOLÓGICA DE CO-\nLOMBIA                                                                                            121
# UNIVERSIDAD DIS- TRITAL FRANCISCO JOSÉ DE\nCALDAS                                                                                                 95
# ...

# %%
# Remove newlines
data["INSTITUCIONES QUE LO AVALAN"] = data["INSTITUCIONES QUE LO AVALAN"].apply(lambda x: ''.join(str(x).split('\n|-')))
# Substitute multiple whitespace with single whitespace
data["INSTITUCIONES QUE LO AVALAN"] = data["INSTITUCIONES QUE LO AVALAN"].apply(lambda x: ' '.join(str(x).split()))
data["INSTITUCIONES QUE LO AVALAN"].value_counts()
# Out:
# UNIVERSIDAD NACIONAL DE COLOMBIA - OFICIAL                                                                                                                                   404
# UNIVERSIDAD DE ANTIOQUIA - UDEA                                                                                                                                              252
# UNIVERSIDAD DEL VALLE - UNIVALLE                                                                                                                                             162
# UNIVERSIDAD NA- CIONAL DE COLOMBIA - OFICIAL                                                                                                                                 127
# UNIVERSIDAD PEDAGÓGICA Y TEC- NOLÓGICA DE CO- LOMBIA                                                                                                                         121
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 8))
data["INSTITUCIONES QUE LO AVALAN"].value_counts()[:20].plot(kind="bar", ax=ax);

# %%
data.to_csv('cleaned_up.csv', index=False)

# %%
data.head()
# Out:
#   CÓDIGO DE GRUPO                                   NOMBRE DEL GRUPO  \
# 0      COL0067371                                            INSIGHT
# 1      COL0165935  GRUPO DE INVESTIGACION E INNOVACIÓN EN ENER-\n...
# 2      COL0110982                                   INSTITUTO ALPINA
# 3      COL0120245          GESTIÓN HOSPITALARIA Y POLÍTICAS DE SALUD
# 4      COL0033023  CENTRO DE INVESTIGA- CIÓN Y DESARROLLO AN- DERCOL
#
#                       LÍDER DEL GRUPO  \
# 0  JAVIER OSWALDO RODRÍGUEZ VELÁSQUEZ
# 1     NHORA CECILIA PA- RRA RODRIGUEZ
# 2            BERNADETTE KLOTZ CEBERIO
# 3               JULIO OROZCO AFRICANO
# 4     DANIEL HUMBERTO BUILES MARTÍNEZ
#
#                          INSTITUCIONES QUE LO AVALAN GRUPO RECONOCIDO  \
# 0  ADMINISTRADORA COUNTRY S.A- CENTRO DE IN- VEST...                
# 1                           AES CHIVOR & CIA SCA ESP                
# 2             ALPINA PRODUC- TOS ALIMENTI- CIOS S.A.                
# ...
